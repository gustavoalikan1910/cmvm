# %%
import psycopg2

conn = psycopg2.connect(
    host='cvmc-postgres',
    database='cvmc_data',
    user='airflow',
    password='airflow'
)

print("Conexão com cvmc_data OK!")
conn.close()
# Out:
# Conexão com cvmc_data OK!
